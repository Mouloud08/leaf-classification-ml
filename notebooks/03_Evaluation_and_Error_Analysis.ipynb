# %% [markdown]
# # 03 - Evaluation et analyse des erreurs
#
# ## TODO
#
# - Recharger les modeles sauvegardes.
# - Generer des predictions propres avec validation croisee.
# - Comparer les performances et analyser les pires confusions.

# %%
from pathlib import Path

# TODO: importer cross_val_predict, LeafDataLoader, ModelEvaluator et les modeles.
# TODO: definir la liste des modeles a evaluer.

MODELS_DIR = Path("../models")

# %% [markdown]
# ## TODO - Analyse scientifique a rediger
#
# - Pourquoi le Perceptron peut echouer dans ce contexte.
# - Comparaison biais-variance entre Random Forest et AdaBoost.
# - Impact du PCA sur les modeles lineaires.
# - Interpretation des confusions entre especes similaires.
