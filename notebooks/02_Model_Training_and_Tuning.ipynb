# %% [markdown]
# # 02 - Entrainement et optimisation des modeles
#
# ## TODO
#
# - Importer les six classes de modeles depuis `src.models`.
# - Charger les donnees avec `LeafDataLoader`.
# - Boucler sur les modeles, lancer l'entrainement et consigner les scores.

# %%
from pathlib import Path
import time

# TODO: importer LeafDataLoader et les 6 modeles.
# TODO: definir le dictionnaire `modeles`.

MODELS_DIR = Path("../models")

# %% [markdown]
# ## TODO - Boucle d'entrainement
#
# - Mesurer le temps de chaque apprentissage.
# - Afficher les meilleurs hyperparametres.
# - Sauvegarder chaque modele dans `models/`.
# - Construire un tableau recapitulatif des meilleurs scores CV.
